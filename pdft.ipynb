# %%
from PIL import Image
import pytesseract
import pdf2image

# Convert PDF pages to images
pages = pdf2image.convert_from_path('test/IPC_JANVIER2025.pdf', 300)

# Use OCR on each page
for page_num, page in enumerate(pages):
    text = pytesseract.image_to_string(page)
    print(f"Page {page_num + 1}:")
    print(text)
# Out:
# Page 1:
# INDICE DES PRIX
#
# A LA CONSOMMATION
#
# Février 2025 ISSN 1111 - 4940
#
# N° 350
# Mois de Janvier 2025
#
# A/ Ville d'Alger
#
# 1. EVOLUTION GLOBALE DE L’INDICE
#
# L’indice brut des prix a la consommation de la ville d'Alger enregistre une hausse de 0,4 % en janvier
# 2025 par rapport au mois précédent. Il y a lieu de rappeler que le méme mois de |’année précédente
# s’est caractérisé par une baisse de 0,3 % en janvier 2024 par rapport a décembre 2023).
#
# Cette augmentation de 0,4%, qui intervient aprés une diminution de 0,7% relevée au mois précédent,
# résulte de la hausse des prix enregistrée au niveau des produits manufacturés qui est de 1,1% et d’un
# degré moindre de celle des prix des biens alimentaires , soit 0,1%.
#
# En effet, les prix des produits agricoles frais connaissent une variation de +0,3%, et ce, en raison
# principalement de l'augmentation des prix de certains produits, tels que les legumes (+3,2%), les fruits
# (+2,7%) et de la pomme de terre (+3,3%). Par contre, plusieurs autres produits affichent des baisses,
# notamment la viande de poulet (-8,7%) et la viande rouge (-0,9%).
#
# Par ailleurs, les prix des produits alimentaires industriels, affichent une baisse, quoique légére, de 0,1%.
# Egalement, les prix des services observent une baisse de prés de 0,9%.
#
# Corrigé des variations saisonniéres, l’indice des prix a la consommation enregistre, pour ce mois de
# janvier 2025, une hausse de 0,5 % par rapport au mois précédent.
#
# Au mois de janvier 2025 et par rapport au méme mois de |’année 2024, la variation des prix a la
# consommation est de +3,7%. Le rythme d’inflation annuel (février 2024 a janvier 2025 / février 2023 a
# janvier 2024) est de +3,8 %.
#
# EVOLUTION PAR CATEGORIE DE PRODUITS
#
# 2.1. Evolution des prix des produits alimentaires
#
# Aprés une baisse de 1,8 % enregistrée le mois précédent, les prix des produits alimentaires connaissent
# une légére hausse de 0,1 % en janvier 2025.
#
# Les prix des produits agricoles frais augmentent de 0,3 %. A l'exception des viandes rouges et blanches
# ainsi que des ceufs, qui enregistrent des baisses respectives de 0,9 %, 8,7 % et 6,7 %, le reste des produits
# de cette catégorie voient leurs prix augmenter, en particulier les légumes (+3,2 %) et les fruits (+2,7 %).
#
# Page 2:
# En revanche, les prix des produits alimentaires industriels se caractérisent par une diminution de 0,1%.
#
# En janvier 2025 et par rapport a janvier 2024, l’évolution des prix des biens alimentaires enregistre
# une hausse de 2,4%. Les prix des produits agricoles frais enregistrent une croissance de 4,9% avec une
# augmentation de 15,2% pour la viande et abats de mouton. Toutefois, les prix des biens alimentaires
# industriels baissent de 0,5% avec un taux de -5,0% pour le café, thé infusion.
#
# 2.2. Produits manufacturés non alimentaires et services
#
# En janvier 2025 et par rapport au mois précédent, les prix des produits manufacturés accusent une
# variation de +1,1%. Les services se distinguent par une baisse de 0,9%.
#
# En janvier 2025 et par rapport au méme mois de |’année précédente, |’évolution des prix des produits
# manufacturés atteint +6,5%, celle des services est de +0,7%.
#
# EVOLUTION PAR GROUPE
# EN JANVIER 2025
# 2001 = 100
# Indice Variation Variation Variation
# Janv. Janv. 25/ Janv. 25/ 01 Mois 25/
# 2025 Déc. 24 Janv. 24 01 Mois 24
# ENSEMBLE 3,69
# Alimentation — Boissons non alcoolisées 2,33
# Habillement — Chaussures 4,18
# Logement — Charges 0,82
# Meubles et Articles d'Ameublement 5,04
# Santé — Hygiéne Corporelle 2,94
# Transports et Communication 0,89
# Education — Culture - Loisirs -4,33
# Divers (N.D.A.) 14,55
# EVOLUTION PAR CATEGORIE DE PRODUITS
# EN JANVIER 2025
# 2001 = 100
#
# Indice Variation Variation Variation
# Poids Janv. Janv. 25/ Janv. 25/ 01 Mois 25/
# 2025 Déc. 24 Janv. 24 01 Mois 24
#
# ENSEMBLE
#
# Biens Alimentaires (y, c, boiss. Alcool.) 2,37
# Produits agricoles frais 4,87
# Produits alimentaires industriels -0,45
#
# Biens manufacturés 6,52
#
# Services
#
#
# Page 3:
# EVOLUTION DE L'INDICE GENERAL BRUT ET DE L'INDICE
# GENERAL AVEC PRODUITS FRAIS DESAISONNALISES
# JANVIER 2024 — JANVIER 2025
#
# 2001 = 100
#
# pndice general 274,32 | 272,73] 277,10] 277,86] 278,26 287,21 | 287,43 | 287,16 284,45
# Indice 275,23 | 273,61] 275,86| 276,61] 277,70 287,59 | 286,97] 285,28 285,40
#
# désaisonnalisé
# Var. Indice
# brut
#
# Var. Indice
# désaisonnalisé
#
# NB : les coefficients saisonniers ont été recalculés sur la base d’une série plus longue
#
# Evolution de l'indice des prix a la consommation
# de la ville d'Alger de Janvier 2024 a Janvier 2025
#
# Glissement annuels de I'indice des prix a la consommation
# de la ville d'Alger de Janvier 2024 a Janvier 2025
#
# =
# z
# >
# a
# B
# S
#
# BS
#
# J F M A M J _JT A s fe) N D J
# Mois
#
#
# Page 4:
# 4
#
# EVOLUTION PAR SOUS-GROUPE
# GROUPE ALIMENTATION BOISSONS NON-ALCOOLISEES
#
# EN JANVIER 2025
# 2001 = 100
# Variation Variation Variation
# Janv. 25/ Janv. 25/ 01 Mois 25/
# Déc. 24 Janv. 24 01 Mois 24
#
# Alimentation- Boissons non Alcoolisées J} 430,9 307,76 2,33
#
# Pain et Céréales 186,59 0,59
# Viandes et abats de mouton 599,89 15,20
# Viandes et abats de boeuf 403,25 1,76
# Volaille - Lapin — Euf 203,01 -21,48
# Poissons Frais 1180,64 19,79
# Viandes et Poissons en conserve 297,14 3,81
# Légumes 340,39 -0,91
# Fruits 354,86 -15,33
# Pomme de Terre 371,27 28,94
# Lait- Fromage- Dérivés 187,22 -2,84
# Huiles et graisses 310,11 -0,56
# Sucre et produits sucrés 237,13 0,84
# Café — Thé — Infusion 300,66 -5,04
# Boissons non alcoolisées 271,04 0,04
#
# Autres produits alimentaires 303,33 7,97
#
# EVOLUTION DES PRODUITS FRAIS (ALIMENTATION)
# EN JANVIER 2025
#
# 2001 = 100
# Indice Variation Variation Variation
#
# Janv. Janv. 25/ Jany. 25/ 01 Mois 25/
# 2025 Déc. 24 Janv. 24 01 Mois 24
#
# Viandes et abats de mouton 15,20
# Viandes et abats de boeuf 1,76
# Viande de poulet -21,52
# CEufs -21,44
# Poissons frais 19,79
# Légumes frais 0,31
# Fruits frais -21,95
# Pomme de terre 28,94
#
#
# Page 5:
# EVOLUTION DES PRIX DE QUELQUES
# PRODUITS ENQUETES DURANT LE MOIS DE JANVIER 2025
#
# Prix Moyens (en DA) Variations (en %)
#
# Intitulé du produit ome 2001 | Janv. | Déc. | Janv. | Janv.25/| Janv. 25/ | Janv. 25/
# natute cu produr Mesure | © 2024 2024 2025 | Déc.24 | Janv.24 2001
#
# VIANDES
#
# Viande de Mouton
#
# Foie de Mouton 599,51
# Tripes de Mouton (Douara 1 Piéce) 475,72
# Téte Pattes Mouton N/Echaudées 428,99
# Beefsteak (Boeuf /Veau) 302,10
# Viande avec Os (Boeuf /Veau) 298,77
# Viande Hachée 307,26
# Foie de Boeuf 461,17
# Tripes de boeuf 407,83
# Merguez Rouge vrac 1kg 1 choix 348,17
# Cachir Rouge Vrac 65,15
# Poulet évidé entier le kg 84,23
#
# uf
# POISSONS
#
# Sardine fraiche
#
# Rouget 451,50
# Pageot 608,54
# Merlan 490,77
#
# Crevette Rouge
#
# LEGUMES FRAIS
#
# Ail sec 225,66
# Ojignon sec 51,38
# Carotte 261,16
# Navet 270,93
# Fenouil 252,93
# Choux fleurs 123,45
# Choux verts 254,66
# Artichaut vert 197,29
# Artichaut violet 190,31
# Carde normale 255,88
# Tomate normale 173,74
# Salade laitue 289,36
# Persil 186,80
# Feéves 169,84
# FRUITS FRAIS
# Citron 203,25
# Orange Thomson 126,64
# Clementine 182,34
# Mandarine 287,56
# Pomme verte 509,87
# Pomme rouge 385,21
#
# *Dans cette colonne, les prix sont annuels moyens sauf pour les légumes et fruits frais, pour
# lesquels ils sont mensuels moyens, (mois de calcul).
#
# Page 6:
# EVOLUTION DES PRIX DE QUELQUES
# PRODUITS ENQUETES DURANT LE MOIS DE JANVIER 2025
#
# Prix Moyens (en DA) Variations (en %)
#
# me 2001 Déc. Nov. Déc. | Déc.24/ | Déc. 24/
# M (*) 2023 2024 2024 | Nov.24 | Déec. 23
# esure
#
# Déc. 24/
#
# Intitulé du produit 2001
#
# FRUITS SECS
#
# Figues séches en vrac 3,89 -6,81 937,18
# Dattes grappe deglet — nour 3,65 -1,81 339,97
# Dattes Muscades Branche 7,29 -7,47 291,22
# Dattes Muscades s/branche 2,61 -5,50 265,35
#
# POMME DE TERRE
#
# Pomme de terre blanche Kg 25,60 73,08 93,49 94,30
# Pomme de terre rouge Kg 23,53 68,58 87,50 88,33
#
# AUTRES PRODUITS
# Baklaoua la piéce 113,33 403,69
# Levure chimique pour gateaux 10 gr 8,98 203,38
# Amandes séches décortiquées vrac lkg 2 118,18 220,42
#
# Huile d'olives traditionnelle 1L 1 194,74 365,93
# Pull-over en cotton local 2 454,17 128,21
# Cont. Assur pour véhic.peug.domm et collis 10 277,73 142,25
# Ardoise l’unité 77,38 231,82
# Stylo a plume 129,52 187,82
# Stylo a feutre ordinaire 1 piéce 42,38 311,86
# Cigarettes brunes filt. Afras paquet de 20 196,25 411,47
# Cigarettes brunes nassim paquet de 20 209,17 404,02
# Cigarettes blondes filt. Gauloise paqt 20 375,21 268,21
# Cigarettes blondes Marlboro paqt 20 439,79 174,87
#
# U
# U
# U
# U
# U
# U
# U
# U
# U
#
# *Dans cette colonne, les prix sont annuels moyens sauf pour les légumes et fruits frais, pour lesquels ils
# sont mensuels moyens, (mois de calcul).
#
# B/ Indice national
#
# L'indice national des prix a la consommation est établi sur la base d'observation des prix effectuée
# auprés d'un échantillon de 17 villes et villages représentatifs des différentes régions du pays.
#
# Cet indice permet essentiellement de disposer d'indicateurs d'évolution des prix de deétail
# sur l'ensemble du territoire national, permettant ainsi une analyse comparative de l'évolution des prix
# entre Alger et les autres régions du pays.
#
# Au mois de janvier 2025 et par rapport au mois précédent, |’indice général des prix a la consommation,
# au niveau national enregistre une hausse de 0,9%.
#
# Les prix des biens alimentaires augmentent de 1,3%.
#
# Page 7:
# EVOLUTION PAR GROUPE
# EN JANVIER 2025
# 2001 = 100
# Indice Variation Variation Variation
# Janv. Janv. 25/ Janv. 25/ 01 Mois 25/
# 2025 Déc. 24 Janv. 24 01 Mois 24
# ENSEMBLE 4,68
# Alimentation - Boissons non alcoolisées 4,33
# Habillement — Chaussures 3,20
# Logement — Charges 1,97
# Meubles et Articles d'Ameublement 4,48
# Santé — Hygiene Corporelle 2,94
# Transports et Communication 1,85
# Education - Culture — Loisirs -0,64
# Divers (N.D.A.) 13,85
#
# EVOLUTION COMPAREE ENTRE LES INDICES DES PRIX A LA CONSOMMATION
# ALGER ET NATIONAL
#
# JANVIER 2024 — JANVIER 2025
# 2001 = 100
#
# 2025
#
# Indice ALGER 274,3 | 272,7) 277,1 | 277,9 | 278,3}) 282,0 | 284,3 | 287,2 | 287,4]) 287,2 285,5 | 283,49 284.5
#
# Général NATIONAL 303,4 | 307,0| 307,9| 307.1 303,1
# Variation ALGER 0,4
# Mensuelle
#
# (en %) NATIONAL 0,9
# Indice ALGER 315,5 | 321,9 307,8
# Alimentation NATIONAL 331,2 | 338,2 323,5
# Variation ALGER 0,1
# Mensuelle
#
# (en %) NATIONAL a
#
# Evolution mensuelle de I'indice général des prix =U Alger
# a la consommation de Janvier 2024 a Janvier 2025 t= National
#
#
# Page 8:
# La ville d'Alger, Le champ d'observation est constitué de 11 secteurs géographiques : Bab-El-Oued, Alger-Centrel, Alger-
# Centre2, El-Biar, Belcourt, El-Harrach, Bir-Mourad-Rais, El Madania, Kouba, Hussein-Dey, Ain Benian.
#
# * L'Enquéte sur les Dépenses de Consommation des Ménages, Elle a consisté en un sondage auprés d'un échantillon de
# 12150 ménages répartis sur l'ensemble du territoire National selon 7 strates, La stratification adoptée repose sur des critéres
# de niveau d'urbanisation et de la zone géographique.
#
# LES PRINCIPALES
# CARACTERISTIQUES DE L'INDICE
#
# * La population de référence est constituée de l'ensemble des ménages d'Alger, de toutes tailles et toutes catégories socio —
# professionnelles.
#
# * L'indice se compose de 261 articles représentés par 791 variétés sélectionnées sur la base de critéres tels que la dépense
# annuelle, la fréquence de la dépense, I'utilité,...
#
# * Les pondérations des variétés sont calculées a partir des dépenses annuelles en 2000, données par I'enquéte nationale sur
# la consommation des ménages, Le taux de couverture de l'indice (en termes de dépenses de consommation) est de 95 %.
#
# * La classification des biens et services consommés en groupes, sous-groupes, articles est proche de celle recommandeée (par
# l'ONU) dans le systeme de comptabilité nationale de 1970.
#
# * L'année de base est 2000 et l'année de référence (100 pour les calculs) est 2001.
# * La périodicité de l'indice est mensuelle, Un indice annuel est aussi calculé.
# * Formule de calcul de l’indice: Imo =di (Wi /Diwi) (p™ /p7i )
#
# wi =poids de la variéteé i,
# ™ = prix courant moyen au mois m de la variété i,
# p 7°; = prix de base (moyen en 2001) de la variété i,
#
# *L'indice national est élaboré selon la méme démarche 4 partir de l'observation des prix auprés d'un échantillon de 17 villes
# et villages représentatifs du territoire national et répartis selon les strates géographiques de l'enquéte sur les dépenses de
# consommation.
#
# * Les fruits et legumes frais, en raison du caractére saisonnier de leur commercialisation, subissent un traitement particulier :
# a partir d'un panier mensuel de pleine saison, il est calculé un indice brut, lequel indice compare les cofits du méme panier
#
# (mensuel) du mois courant et du mois de méme nom de I'année de référence (2001). Les prix de base des variétés du panier,
# ainsi que les pondérations, sont mensuels, La comparaison d'indices bruts de mois de noms différents indique, non pas une
# variation (relative) pure des prix, mais le rapport des variations de prix pour chacun des mois.
#
# * Les relevés de prix sont effectués périodiquement auprés d’un échantillon de points de vente selon un programme
# d’enquétes fixé pour chaque groupe de produits
#
# Indice des prix 4 la consommation /Office National des Statistiques,
#
# Dir. Taoufik HADJ MESSAOUD.- N° 1 (1996)- _.- Alger: ONS, 2025. -
# 08p.-tabl, graph. ; 29,7cm, Mensuel
#
# Notice établie d’aprés le N°349 (2025),
#
# ISSN : 1111 - 4940 = indice des prix 4 la consommation
#
# Succéde aprés scission a : “données statistiques ” =ISSN 1111 - 5939
# Prix/indice de prix/Alger/ Algérie/2025/
#
# Directeur de la publication : Taoufik HADJ MESSAOUD
# Administration : DPDDI/ONS 8 & 10, rue des Moussebiline - Alger
# Montage et Impression : Les ateliers de l’imprimerie de PONS
#
# 8 & 10, rue des Moussebiline - Alger
#
# E-MAIL: ons@ons.dz stat@ons,dz Site Web- http://www.ons.dz
# BE&E : (021) 63-98-06
#
# Diffusion : DPDDI/ONS ISSN 1111 — 4940
